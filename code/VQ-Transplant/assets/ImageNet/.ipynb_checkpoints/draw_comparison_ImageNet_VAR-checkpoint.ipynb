# %%
import os
import json
from PIL import Image, ImageDraw, ImageFont
from pprint import pprint

# %%
manul_picked = [
    "004339.png",
    "013772.png",
    "016954.png",
    "048662.png",
    "047779.png",
    "011531.png",
    "017008.png",
    "016995.png"
]

# %%
original_images = []
wasserstein_var_images = []


# Base directory for images
base_dir = 'D:\VQProjects\Github Code\Wasserstein-VQ\code\VQ-Transplant\\assets\ImageNet'


for key in manul_picked:
    # image path
    original_img_path = os.path.join(base_dir, 'Original', key)
    wasserstein_var_img_path = os.path.join(base_dir, 'Wasserstein_VAR', key)

    # Load images
    original_img = Image.open(original_img_path)
    wasserstein_var_img = Image.open(wasserstein_var_img_path)

    original_images.append(original_img)
    wasserstein_var_images.append(wasserstein_var_img)
    
# Get image size
img_width, img_height = original_images[0].size

# Canvas dimensions
canvas_width = img_width * 8
canvas_height = img_height * 2

# Create canvas
canvas = Image.new('RGB', (canvas_width, canvas_height), 'white')

font_path = os.path.join("C:", "Windows", "Fonts", "times.ttf")
# Font setup
try:
    font = ImageFont.truetype(font_path, size=22)
    print("Font loaded successfully")
except IOError:
    font = ImageFont.load_default()
    print("Font not loaded, using default font")

draw = ImageDraw.Draw(canvas)

# Titles for each row
titles = [
    'Original',
    'Wasserstein VAR',
]

# Paste images onto the canvas and add row titles
for row_index, (title, images) in enumerate(zip(titles, [original_images, wasserstein_var_images])):
    for col_index, img in enumerate(images):
        x_position = col_index * img_width
        y_position = row_index * img_height
        canvas.paste(img, (x_position, y_position))

    # Add the row title at the top-left corner of the first image in the row
    title_position = (5, row_index * img_height + 5)
    draw.text(title_position, title, fill=(255, 255, 255, 255), font=font)

# Save the final image
canvas.save('VAR_Visualization_On_ImageNet.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-648432aaa965> in <module>
#      14     # Load images
#      15     original_img = Image.open(original_img_path)
# ---> 16     wasserstein_var_img = Image.open(wasserstein_var_img_path)
#      17
#      18     original_images.append(original_img)
#
# d:\tools\python3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\VQProjects\\Github Code\\Wasserstein-VQ\\code\\VQ-Transplant\\assets\\ImageNet\\Wasserstein_VAR\\004339.png'
